# %%
x = 10%2
x = 10//2
x = 10**2
print(x)
# Out:
# 100

# %%
x += 10
x -= 10
x *= 10
x /= 10 
print(x)
# Out:
# 100.0

# %%
x += 10
print(x)
# Out:
# 110.0

# %%
x = 10.5
y = 20.8
print(x < y)
print(x > y)
print(x <= y)
print(x >= y)
print(x == y)
print(x != y)
# Out:
# True
# False
# True
# False
# False
# True

# %%
"A" > "a"
# Out:
# False

# %%
"apple" > "banana"
# Out:
# False

# %%
x = 3
x > 5 and x < 1
# Out:
# False

# %%
x = 3 
not (x > 5 or x < 1)
# Out:
# True

# %%
not(x > 5 or x > 1)
# Out:
# False

# %%
x = [ 2, 3, 4]
y = [ 2, 3, 4]
z = x
print (x is y)
print (x == y)
print (x is z)
# Out:
# False
# True
# True

# %%
x = ['apple', 'banana', 'mango']
print("mango" in x)
# membership operator
# Out:
# True

# %%
# if else condition: 
x = 5
if x > 10:
    print("yes")

elif x > 20:
    print("no")

else:
    print("out")
# Out:
# out

# %%
x = 131
if ( x > 100 ):
    if ( x % 2 == 0 ):
        print("even")
        
    else:
        print("odd")
    print("value is greater than 100")
else:
    print("less than 100")
# Out:
# odd
# value is greater than 100

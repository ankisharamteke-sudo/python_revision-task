# %%
x="250"
y=int(x)
print(y)
print(type(y))
# Out:
# 250
# <class 'int'>

# %%
num = 99
a = float(num)
b = str(num)
print(a)
print(b)
# Out:
# 99.0
# 99

# %%
x = "45.67"
f = float(x)
i =int(f)
print(f)
print(i)
# Out:
# 45.67
# 45

# %%
b = False 
print(int(b))
# Out:
# 0

# %%
t = (10, 20, 30)
j = list(t)
print(j)
# Out:
# [10, 20, 30]

# %%
nums = [1, 2, 3, 4, 5]
print(nums[0])
print(nums[-1])
print(len(nums))
# Out:
# 1
# 5
# 5

# %%
s ="MachineLearning"
print(s[:7])
print(s[-5:])
# Out:
# Machine
# rning

# %%
t = (1, 2, 3, 4)

# %% [markdown]
# s = "python"
# j = list(s)
# print(j)

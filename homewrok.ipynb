# %%
x = [ "apple", "banana", "cherry"]
x.append("orange")
print(x)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
x = [10, 20, 30, 40, 50]
x[1] = 25
print(x)
# Out:
# [10, 25, 30, 40, 50]

# %%
x = [ "apple", "banana", "cherry"]
x.remove("banana")
print(x)
# Out:
# ['apple', 'cherry']

# %%
t = [4.0, 5.0]
print(t[0])
# Out:
# 4.0

# %%
colors = ["red", "green", "blue"]
print(type(colors))
print(len(colors))
# Out:
# <class 'list'>
# 3

# %%
alphabet = ["a", "b", "c", "d", "e"]
alphabet.append("f")
print(alphabet)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
t = (5,)
print(t)
print(type(t))
# Out:
# (5,)
# <class 'tuple'>

# %%
list_1 = ["brand", "model", "year"]
list_2 = [" ford", "mustang", 1964]
new_D = zip(list_1, list_2)
print(dict(new_D))
# Out:
# {'brand': ' ford', 'model': 'mustang', 'year': 1964}

# %%
fruits_set = ["apple", "banana", "cherry"]
fruits_set.append("apple")
print(fruits_set)
# Out:
# ['apple', 'banana', 'cherry', 'apple']

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union = set1.union(set2)
print(union)
# Out:
# {1, 2, 3, 4, 5}

# %%
x = "100"
y = int(x)
addition = y + 50
print(addition)
# Out:
# 150

# %%
y = "10.75"
z = int(float(y))
print(z)
# Out:
# 10

# %%
my_list = [1, 2, 2, 3, 4, 4]
set = set(my_list)
print(set)
# Out:
# {1, 2, 3, 4}

# %%
A = [3]
B = int(float(A[0]))
multiplication = B * 2
print(multiplication)
# Out:
# 6

# %%
radius = float(input("Enter radius: "))
area = 3.14 * radius * radius
print("Area of circle:", area)
# Out:
# Area of circle: 772.007936

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

quotient = a // b
remainder = a % b

print("Quotient:", quotient)
print("Remainder:", remainder)
# Out:
# Quotient: 0
# Remainder: 3

# %%
radius = float(input("Enter radius: "))
volume = (4/3) * 3.14 * radius**3
print("Volume of sphere:", volume)
# Out:
# Volume of sphere: 7696.205416666667

# %%
balance = 1000
balance += 500
print("Updated balance:", balance)
# Out:
# Updated balance: 1500

# %%
number = 10
number **= 2
print(number)
# Out:
# 100

# %%
count = 2
count *= 10
count -= 4
count /= 2
print("Final result:", count)
# Out:
# Final result: 8.0

# %%
num = int(input("Enter a number: "))
print(num > 0)
# Out:
# True

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

print(len(str1) == len(str2))
# Out:
# True

# %%
age = int(input("Enter your age: "))

senior = age >= 65
junior = age <= 12

print("Senior Discount:", senior)
print("Junior Discount:", junior)
# Out:
# Senior Discount: False
# Junior Discount: False

# %%
num = int(input("Enter number: "))
print(num > 10 and num < 50)
# Out:
# True

# %%
has_password = True
has_fingerprint = False

print(has_password or has_fingerprint)
# Out:
# True

# %%
year = int(input("Enter year: "))

is_leap = (year % 4 == 0) and (year % 100 != 0 or year % 400 == 0)
print("Leap Year:", is_leap)
# Out:
# Leap Year: False

# %%
x = 10
y = 10

print(x is y)
# Out:
# True

# %%
def check_none(value):
    return value is None

print(check_none(None))
# Out:
# True

# %%
x=1
x
# Out:
# 1

# %%
x=26
print(x)
print(type(x))
# Out:
# 26
# <class 'int'>

# %%
n = "250"
print(type(n))
# Out:
# <class 'str'>

# %%
n_int = int(n)
print(f"{'n_type'}:{type(n_int)}")
print(f"{n}: The type of 'n' is {type(n)}")
# Out:
# n_type:<class 'int'>
# 250: The type of 'n' is <class 'str'>

# %%
fl = "45.57"
print(type(fl))
f2 = int(float(fl))
print(type(f2))
f2
# Out:
# <class 'str'>
# <class 'int'>
# 45

# %%
list_5 = [x for x in range(1,6)]
print(list_5)
print(1)
print(5)
print(len(list_5))
s = "MachineLearning"
# Out:
# [1, 2, 3, 4, 5]
# 1
# 5
# 5

# %%
list_A = [x for x in range(1, 11)]
list_B = ['A', 'B', 'C', 'D', 'F', 'G', 'H', 'I', 'J']

new_D = zip(list_A, list_B)
print(dict(new_D))
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'F', 6: 'G', 7: 'H', 8: 'I', 9: 'J'}
